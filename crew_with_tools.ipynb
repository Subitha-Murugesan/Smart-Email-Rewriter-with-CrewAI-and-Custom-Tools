# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1
)
llm.call("Who invented transcendental meditation.")

#first call usually takes longer
# Out:
# 'Transcendental Meditation (TM) was popularized by **Maharishi Mahesh Yogi**.\n'

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    tools=[SerperDevTool()],
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic} as of 2025.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 4333cda3-72f3-49e8-afd2-c75c11aec567                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of 2025.                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/subitham/Documents/Studies/Job_Study/Agentic AI/Crewai/crewaiproject/.venv/lib/python3.13/site-packages/rich/live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/subitham/Documents/Studies/Job_Study/Agentic
# AI/Crewai/crewaiproject/.venv/lib/python3.13/site-packages/rich/live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Thought: I need to find 3-5 interesting and recent facts about the future of electric vehicles. I will use     │
# │  the search tool to find this information. I will focus on facts that are relevant to the year 2025 or beyond.  │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "future of electric vehicles 2025 facts"                                                     │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'future of electric vehicles 2025 facts', 'type': 'search', 'num': 10, 'engine':    │
# │  'google'}, 'organic': [{'title': 'Global EV Outlook 2025 – Analysis - IEA', 'link':                            │
# │  'https://www.iea.org/reports/global-ev-outlook-2025', 'snippet': 'The Global EV Outlook is an annual           │
# │  publication that reports on recent developments in electric mobility around the world.', 'position': 1,        │
# │  'sitelinks': [{'title': 'Trends in electric car markets', 'link':                                              │
# │  'https://www.iea.org/reports/global-ev-outlook-2025/trends-in-electric-car-markets-2'}, {'title': 'Outlook     │
# │  for electric mobility', 'link':                                                                                │
# │  'https://www.iea.org/reports/global-ev-outlook-2025/outlook-for-electric-mobility'}, {'title': 'Executive      │
# │  summary', 'link': 'https://www.iea.org/reports/global-ev-outlook-2025/executive-summary'}]}, {'title':         │
# │  'Electric Vehicle Outlook | BloombergNEF', 'link':                                                             │
# │  'https://about.bnef.com/insights/clean-transport/electric-vehicle-outlook/', 'snippet': "The Electric Vehicle  │
# │  Outlook is BNEF's annual flagship report looking at how electrification and other changes will impact road     │
# │  transport in the years ahead.", 'position': 2}, {'title': 'Future EVs: Every Electric Vehicle Coming Soon -    │
# │  Car and Driver', 'link': 'https://www.caranddriver.com/news/g29994375/future-electric-cars-trucks/',           │
# │  'snippet': 'Ford Project T3 (Expected: 2028)\u200b\u200b Ford had originally intended to launch its            │
# │  next-generation electric truck—codenamed Project T3—for 2025, ...', 'position': 3}, {'title': 'Electric        │
# │  Vehicle Benefits and Considerations', 'link': 'https://afdc.energy.gov/fuels/electricity-benefits',            │
# │  'snippet': 'EVs improve fuel economy, lower costs, reduce emissions, and offer safety benefits. Purchase       │
# │  prices can be higher, but fuel costs are lower. All-electric ...', 'position': 4}, {'title': 'What Is the      │
# │  Future of Electric Cars? - Progressive', 'link':                                                               │
# │  'https://www.progressive.com/answers/future-of-electric-cars/', 'snippet': 'When compared to gas-powered       │
# │  cars, electric vehicles have lower carbo...                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/subitham/Documents/Studies/Job_Study/Agentic
# AI/Crewai/crewaiproject/.venv/lib/python3.13/site-packages/rich/live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I have the search results. I will extract 3-5 interesting facts about the future of          │
# │  electric vehicles as of 2025.                                                                                  │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "Global EV sales forecast 2025"                                                              │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Global EV sales forecast 2025', 'type': 'search', 'num': 10, 'engine': 'google'},  │
# │  'organic': [{'title': 'Global EV Outlook 2025 – Analysis - IEA', 'link':                                       │
# │  'https://www.iea.org/reports/global-ev-outlook-2025', 'snippet': 'The Global EV Outlook is an annual           │
# │  publication that reports on recent developments in electric mobility around the world.', 'position': 1,        │
# │  'sitelinks': [{'title': 'Executive summary', 'link':                                                           │
# │  'https://www.iea.org/reports/global-ev-outlook-2025/executive-summary'}, {'title': 'Global EV Data Explorer',  │
# │  'link': 'https://www.iea.org/data-and-statistics/data-tools/global-ev-data-explorer'}, {'title': 'Trends in    │
# │  electric car markets', 'link':                                                                                 │
# │  'https://www.iea.org/reports/global-ev-outlook-2025/trends-in-electric-car-markets-2'}]}, {'title': 'Electric  │
# │  Vehicle Outlook | BloombergNEF', 'link':                                                                       │
# │  'https://about.bnef.com/insights/clean-transport/electric-vehicle-outlook/', 'snippet': '25. %. Expected       │
# │  growth in global passenger EV sales in 2025 ; 3 .8TWh. Risk-adjusted lithium-ion cell manufacturing capacity   │
# │  by the end of 2025 – double expected ...', 'position': 2}, {'title': '[PDF] Electric Vehicle Sales Review      │
# │  Q2-2025 | PwC and Strategy', 'link':                                                                           │
# │  'https://www.pwc.com/hu/hu/kiadvanyok/assets/pdf/strategyand-electric-vehicle-sales-review-q2-2025.pdf',       │
# │  'snippet': 'Global BEV sales enjoyed substantial growth year on year in the second quarter of 2025,            │
# │  increasing by 33% compared to Q2 2024. Almost one in five cars (19%) ...', 'position': 3}, {'title': 'EV       │
# │  adoption rates: How the US and other markets compare in 2025', 'link':                                         │
# │  'https://www.spglobal.com/automotive-insights/en/blogs/2025/10/ev-adoption-rates-how-us-and-other-markets-com  │
# │  pare-2025', 'snippet': "In 2025, NEVs reached 50% of new sales, overtaking ICE vehicles for the first time.    │
# │  Its NEV sales exceed the combined total of the EU's five ...", 'position': 4}, {'title': '[PDF] Global EV      │
# │  Outlook 2025 - NET', 'link': 'https://iea.blob.core.windows.net/assets/7ea38b60-3033-42a6-9589-...             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  *   Global EV sales are expected to increase by 25% in 2025, similar to the growth rate in 2024.               │
# │  *   EV sales in Q1 2025 grew by 35% compared to Q1 2024.                                                       │
# │  *   In Q3 2025, electric vehicle sales in the U.S. hit an all-time high of 438,487 units.                      │
# │  *   NEV (New Energy Vehicles) sales in China reached 50% of new sales in 2025, overtaking ICE (Internal        │
# │  Combustion Engine) vehicles for the first time.                                                                │
# │  *   Global BEV (Battery Electric Vehicle) sales increased by 33% in Q2 2025 compared to Q2 2024, representing  │
# │  almost one in five cars sold (19%).                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: e0ba80c0-19bc-4b5f-9a8a-6fd8f032512c                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# /Users/subitham/Documents/Studies/Job_Study/Agentic AI/Crewai/crewaiproject/.venv/lib/python3.13/site-packages/rich/live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Road Ahead: Electric Vehicle Sales Surge in 2025**                                                       │
# │                                                                                                                 │
# │  The electric vehicle revolution is accelerating! Global EV sales are projected to jump by 25% in 2025,         │
# │  mirroring the impressive growth seen in 2024. The year started strong, with Q1 sales up 35% compared to the    │
# │  previous year. By Q3, the U.S. market reached a record high of 438,487 EV units sold. China is leading the     │
# │  charge, with New Energy Vehicles (NEVs) now accounting for 50% of all new car sales, surpassing traditional    │
# │  gasoline cars. Globally, Battery Electric Vehicle (BEV) sales soared by 33% in Q2, representing nearly one in  │
# │  five cars sold (19%). The future of transportation is electric, and the momentum is undeniable.                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 32d5e49b-61fc-4f7f-9de3-36294153b373                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw='**The Road Ahead: Electric Vehicle Sales Surge in 2025**\n\nThe electric vehicle revolution is accelerating! Global EV sales are projected to jump by 25% in 2025, mirroring the impressive growth seen in 2024. The year started strong, with Q1 sales up 35% compared to the previous year. By Q3, the U.S. market reached a record high of 438,487 EV units sold. China is leading the charge, with New Energy Vehicles (NEVs) now accounting for 50% of all new car sales, surpassing traditional gasoline cars. Globally, Battery Electric Vehicle (BEV) sales soared by 33% in Q2, representing nearly one in five cars sold (19%). The future of transportation is electric, and the momentum is undeniable.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles as of 2025.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles as of 2025.', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw='*   Global EV sales are expected to increase by 25% in 2025, similar to the growth rate in 2024.\n*   EV sales in Q1 2025 grew by 35% compared to Q1 2024.\n*   In Q3 2025, electric vehicle sales in the U.S. hit an all-time high of 438,487 units.\n*   NEV (New Energy Vehicles) sales in China reached 50% of new sales in 2025, overtaking ICE (Internal Combustion Engine) vehicles for the first time.\n*   Global BEV (Battery Electric Vehicle) sales increased by 33% in Q2 2025 compared to Q2 2024, representing almost one in five cars sold (19%).', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: Research interesting facts about the topic: The future of electrical vehicles\nYou ONLY have access to the following tools, and should NEVER make up tools that are not listed here:\n\nTool Name: Search the internet with Serper\nTool Arguments: {\'search_query\': {\'description\': \'Mandatory search query you want to use to search the internet\', \'type\': \'str\'}}\nTool Description: A tool that can be used to search the internet with a search_query. Supports different search types: \'search\' (default), \'news\'\n\nIMPORTANT: Use the following format in your response:\n\n```\nThought: you should always think about what to do\nAction: the action to take, only one name of [Search the internet with Serper], just the name, exactly as it\'s written.\nAction Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " to wrap keys and values.\nObservation: the result of the action\n```\n\nOnce all necessary information is gathered, return the following format:\n\n```\nThought: I now know the final answer\nFinal Answer: the final answer to the original input question\n```'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of 2025.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nBegin! This is VERY important to you, use the tools available and give your best Final Answer, your job depends on it!\n\nThought:'}, {'role': 'assistant', 'content': 'I need to find 3-5 interesting and recent facts about the future of electric vehicles. I will use the search tool to find this information. I will focus on facts that are relevant to the year 2025 or beyond.\n\nAction: Search the internet with Serper\nAction Input: {"search_query": "future of electric vehicles 2025 facts"}\nObservation: {\'searchParameters\': {\'q\': \'future of electric vehicles 2025 facts\', \'type\': \'search\', \'num\': 10, \'engine\': \'google\'}, \'organic\': [{\'title\': \'Global EV Outlook 2 ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 4333cda3-72f3-49e8-afd2-c75c11aec567                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **The Road Ahead: Electric Vehicle Sales Surge in 2025**                                         │
# │                                                                                                                 │
# │  The electric vehicle revolution is accelerating! Global EV sales are projected to jump by 25% in 2025,         │
# │  mirroring the impressive growth seen in 2024. The year started strong, with Q1 sales up 35% compared to the    │
# │  previous year. By Q3, the U.S. market reached a record high of 438,487 EV units sold. China is leading the     │
# │  charge, with New Energy Vehicles (NEVs) now accounting for 50% of all new car sales, surpassing traditional    │
# │  gasoline cars. Globally, Battery Electric Vehicle (BEV) sales soared by 33% in Q2, representing nearly one in  │
# │  five cars sold (19%). The future of transportation is electric, and the momentum is undeniable.                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
